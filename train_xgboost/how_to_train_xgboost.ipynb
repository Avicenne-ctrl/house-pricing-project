# %% [markdown]
# # Train XGBoost

# %% [markdown]
# In the project folder create a trainer folder

# %%
! mkdir trainer
# Out:
# mkdir: trainer: File exists

# %% [markdown]
# # Python fine tuning script

# %% [markdown]
# Then create in trainer your task.py fil in which we want to fine tune hyperparameters for XGBoost

# %%
# %%writefile trainer/train.py
#first line creates the file in the trainer folder

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import pandas as pd
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
import numpy
import configparser
from google.cloud import storage
import sys
sys.path.append("..")
import tensorflow as tf
from tensorflow.keras.datasets import boston_housing


JOB_NAME  = "house-pricing-train-job"
PROJECT   = "trans-sunset-439207-f2"
LOCATION  = "us-central1"
BUCKET_ID = "trans-sunset-439207-f2-house-pricing"

parser = argparse.ArgumentParser()
parser.add_argument('--l_r', dest='lr', default=0.001, type=float, help='learning rate')
parser.add_argument('--n_estimators', dest='n_estimators', default=100, type=int, help='n_estimators')
parser.add_argument( '--max_depth',dest='max_depth',  default=6, type=int, help='max_depth')
parser.add_argument( '--subsample', dest='subsample', default=0.8, type=float, help='subsample')

args = parser.parse_args()


def save_model_to_bucket(model_trained : XGBRegressor):
    """Save the trained model to the bucket

    Args:
        model_trained (XGBRegressor): 
            trained model
    """
    
    # save it to the bucket
    bst = model_trained.get_booster()
    bst.save_model('/tmp/xgboost_model.bst')
    storage_client = storage.Client()

    bucket = storage_client.bucket(BUCKET_ID)
    blob = bucket.blob("xgboost-model/model_xgboost.bst")

    # Uploader le fichier local vers le blob
    blob.upload_from_filename('/tmp/xgboost_model.bst')
    


def create_xgboost(n_estimators: int, 
                   max_depth: int, 
                   learning_rate: float, 
                   subsample: float):
    """
    create the xgboost regressor model with hyperparameters
    
    Args:
        n_estimators (int):
        
        max_depth (int):
        
        learning_rate (float):
        
        subsample (float):
        
        
    Returns:
        xgb (XGBRegressor):
            model init with hyperparameters

    """
    xgb = XGBRegressor(n_estimators= n_estimators, 
                       max_depth=max_depth, 
                       learning_rate=learning_rate, 
                       subsample=subsample)
    return xgb




def train_xgboost(x_train: pd.DataFrame, x_val: pd.DataFrame, y_train: pd.Series, y_val: pd.Series):
    """
        train and then save the xgboost model

        Args:
            x_train (pd.DataFrame):
                    training dataset
                    
            x_val (pd.DataFrame):
                validation dataset
                
            y_train (pd.Series): 
                label for training dataset
                
            y_val (pd.Series):
                label for validation dataset

        Returns:
            XGBRegressor: 
                trained model
        
        Raise:
        ------
            - ValueType Error
            - if input are not numpy.array
    """
    
    if not isinstance(x_train, pd.DataFrame) or not isinstance(x_val, pd.DataFrame) or not isinstance(y_train, pd.Series) or not isinstance(y_val, pd.Series):
        raise TypeError(f"Wrong type for data, expected pd.DataFrame or pd.Series got x_train: {type(x_train).__name__}, "
                        f"x_val: {type(x_val).__name__}, y_train: {type(y_train).__name__}, "
                        f"y_val: {type(y_val).__name__}")
        
        
    # get params from bucket
    l_r, n_estimators, max_d, subsamples = get_hyperparams_xgboost()
    
    xgb = create_xgboost(n_estimators, max_d, l_r, subsamples) 
    xgb.fit(x_train, y_train)
    pred = xgb.predict(x_val)
    score = r2_score(y_val, pred)
    
    return xgb

def load_data():
    
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.boston_housing.load_data(
        path="boston_housing.npz", test_split=0.2, seed=113
    )

    columns = [
        "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", 
        "TAX", "PTRATIO", "B", "LSTAT"
    ]

    # Convertir les ensembles de données en DataFrames pandas
    return pd.DataFrame(x_train, columns=columns), pd.Series(y_train), pd.DataFrame(x_test, columns=columns), pd.Series(y_test)


with strategy.scope():
  # Creation of dataset, and model building/compiling need to be within
  # `strategy.scope()`.
  xgboost = create_xgboost(args.n_estimators, args.max_depth, args.l_r, args.subsample)
    
x_train, y_train, x_val, y_val = load_data()

# train and save the new model
xgb_trained = train_xgboost(x_train, x_val, y_train, y_val)

save_model_to_bucket(xgb_trained)
# Out:
# Overwriting trainer/train.py

# %% [markdown]
# # Dockerfile

# %% [markdown]
# Then we will need to create a Dockerfile in order to create the container and send it to Google Cloud (Artifact Registry)

# %%
# %%writefile Dockerfile
#
# FROM python:3.9-slim
#
# # Avoiding crash due to scikit-learn and xgboost installation
# RUN apt-get update && apt-get install -y \
#     build-essential \
#     libatlas-base-dev \
#     && rm -rf /var/lib/apt/lists/*
#
# ENV APP_HOME /app
# WORKDIR $APP_HOME
# COPY . ./
#
# RUN pip install -r requirements.txt
# CMD ["python", "trainer/train.py"]
# Out:
# Overwriting Dockerfile

# %% [markdown]
# # Google Cloud

# %% [markdown]
# ### auth and connect to your project

# %%
# !gcloud auth application-default login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=H7u8cIqhI06fBpw0VQPU152LGQ7qg7&access_type=offline&code_challenge=ZwxP9WzyfcHfdRHrysLZC5EM3KEdsYnWUJJrpc8_r6o&code_challenge_method=S256
#
#
# Credentials saved to file: [/Users/avicenne/.config/gcloud/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
#
# Quota project "trans-sunset-439207-f2" was added to ADC which can be used by Google client libraries for billing and quota. Note that some services may still bill the project owning the resource.

# %%
PROJECT_ID = "trans-sunset-439207-f2"
BUCKET_URI = f"gs://{PROJECT_ID}-boston-house-pricing" 
LOCATION = "us-central1"
IMAGE_NAME = "xgboost-train"
IMAGE_URI = f"gcr.io/{PROJECT_ID}/{IMAGE_NAME}"

# %%
# select the project
# !gcloud config set project $PROJECT_ID

# check if bucket already exist
# !gsutil ls gs://dist-$PROJECT_ID-unique

#if not create it
! gsutil mb -l $LOCATION $BUCKET_URI
# Out:
# Updated property [core/project].
# gs://dist-trans-sunset-439207-f2-unique/xgboost/
# Creating gs://trans-sunset-439207-f2-boston-house-pricing/...
# ServiceException: 409 A Cloud Storage bucket named 'trans-sunset-439207-f2-boston-house-pricing' already exists. Try another name. Bucket names must be globally unique across all Google Cloud projects, including those outside of your organization.

# %% [markdown]
# ### Docker Build

# %%
# !docker build ./ -t $IMAGE_URI
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.5s
# [+] Building 0.6s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.6s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.7s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         0.9s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.0s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.2s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.2s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
# [+] Building 1.5s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 29B                                           0.2s
# [+] Building 1.7s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.3s
#  => => transferring context: 29B                                           0.3s
# [+] Building 1.8s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 29B                                           0.5s
# [+] Building 2.0s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.6s
#  => => transferring context: 29B                                           0.6s
# [+] Building 2.1s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.8s
#  => => transferring context: 29B                                           0.8s
# [+] Building 2.3s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 29B                                           0.9s
# [+] Building 2.4s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.1s
#  => => transferring context: 29B                                           1.1s
# [+] Building 2.6s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.2s
#  => => transferring context: 29B                                           1.2s
# [+] Building 2.7s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.3s
#  => => transferring context: 47.55kB                                       1.3s
# [+] Building 2.8s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.5s
#  => => transferring context: 47.55kB                                       1.5s
# [+] Building 3.0s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.6s
#  => => transferring context: 47.55kB                                       1.6s
# [+] Building 3.1s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.8s
#  => => transferring context: 47.55kB                                       1.8s
# [+] Building 3.2s (5/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
# [+] Building 3.4s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.2s
# [+] Building 3.6s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.3s
# [+] Building 3.7s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.5s
# [+] Building 3.9s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.6s
# [+] Building 4.0s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.8s
# [+] Building 4.2s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              0.9s
# [+] Building 4.3s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.1s
# [+] Building 4.5s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.2s
# [+] Building 4.6s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.4s
# [+] Building 4.6s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.4s
#  => => # Collecting google-cloud-aiplatform
# [+] Building 4.8s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.5s
#  => => # Collecting google-cloud-aiplatform
# [+] Building 4.8s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.5s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 4.9s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.7s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.1s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              1.8s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.2s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.0s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.4s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.1s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.5s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.3s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.7s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.4s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 5.8s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.6s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.0s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.7s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.1s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              2.9s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.3s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.0s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.4s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.2s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.6s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.3s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.7s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.5s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 6.9s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.6s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
#  => => #  MB)
# [+] Building 7.0s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                              3.8s
#  => => # Collecting google-cloud-aiplatform
#  => => #   Downloading google_cloud_aiplatform-1.70.0-py2.py3-none-any.whl (5.3
# ...
#  => => exporting layers                                                    0.3s
# [+] Building 105.2s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 105.3s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 105.5s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 105.6s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 105.8s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 105.9s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 106.1s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 106.2s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 106.4s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 106.5s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 106.6s (10/11)                                docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
#  => => writing image sha256:42e688821e396d50c9f795dcf54861d03152c2b4782fc  0.0s
# [+] Building 106.7s (11/11) FINISHED                       docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 368B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim         1.3s
#  => [auth] library/python:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/library/python:3.9-slim@sha256:7a9cd42706c174cdc  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 47.66kB                                       1.9s
#  => CACHED [2/5] RUN apt-get update && apt-get install -y     build-essen  0.0s
#  => CACHED [3/5] WORKDIR /app                                              0.0s
#  => [4/5] COPY . ./                                                        0.0s
#  => [5/5] RUN pip install -r requirements.txt                            101.5s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
#  => => writing image sha256:42e688821e396d50c9f795dcf54861d03152c2b4782fc  0.0s
#  => => naming to gcr.io/trans-sunset-439207-f2/xgboost-train               0.0s
#
#  1 warning found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "ENV key=value" should be used instead of legacy "ENV key value" format (line 10)
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# !docker push $IMAGE_URI
# Out:
# Using default tag: latest
# The push refers to repository [gcr.io/trans-sunset-439207-f2/xgboost-train]
#
# 73343c28: Preparing
# 68cd70bc: Preparing
# 93120a04: Preparing
# 52a835b1: Preparing
# 044002b3: Preparing
# 64a1b270: Preparing
# 574d28ce: Preparing
# 64a1b270: Waiting g denied: Unauthenticated request. Unauthenticated requests do not have permission "artifactregistry.repositories.uploadArtifacts" on resource "projects/trans-sunset-439207-f2/locations/us/repositories/gcr.io" (or it may not exist)

# %% [markdown]
# ### Vertex Ai training

# %%
from google.cloud import aiplatform
from google.cloud.aiplatform import hyperparameter_tuning as hpt
import vertexai.preview

# %%
aiplatform.init(project=PROJECT_ID, staging_bucket=BUCKET_URI)

worker_pool_specs = [
    {
        "machine_spec": {
            "machine_type": "n1-standard-4",
        },
        "replica_count": 1,
        "container_spec": {"image_uri": IMAGE_URI},
    }
]


# Create a CustomJob

JOB_NAME = "xgboost-train-job"

train_job = aiplatform.CustomJob(
    display_name=IMAGE_NAME,
    project=PROJECT_ID,
    worker_pool_specs=worker_pool_specs,
    staging_bucket=BUCKET_URI,
)

# %%
# Load the hyperparams from the previous Xgboost CustomJob
JOB_NAME = "house-pricing-hyperparam-job"

hpt_job = aiplatform.HyperparameterTuningJob.get(
        resource_name=JOB_NAME,
    )

"""CMDARGS = [
        "--l_r=" + ,
        "--n_estimators=" + ,
        "--max_depth=" + ,
        "--subsample=" + ,
    ]"""

# %%
train_job.run()
# Out:
# Creating CustomJob
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:1181, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1175 (
#    1176     state,
#    1177     call,
#    1178 ) = self._blocking(
#    1179     request, timeout, metadata, credentials, wait_for_ready, compression
#    1180 )
# -> 1181 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.RESOURCE_EXHAUSTED
# 	details = "The following quota metrics exceed quota limits: aiplatform.googleapis.com/custom_model_training_cpus"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv6:%5B2a00:1450:4007:818::200a%5D:443 {created_time:"2024-10-27T10:36:03.209172+01:00", grpc_status:8, grpc_message:"The following quota metrics exceed quota limits: aiplatform.googleapis.com/custom_model_training_cpus"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_job.run()
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/jobs.py:2317, in CustomJob.run(self, service_account, network, timeout, restart_job_on_worker_restart, enable_web_access, experiment, experiment_run, tensorboard, sync, create_request_timeout, disable_retries, persistent_resource_id, scheduling_strategy, max_wait_duration)
#    2314 network = network or initializer.global_config.network
#    2315 service_account = service_account or initializer.global_config.service_account
# -> 2317 self._run(
#    2318     service_account=service_account,
#    2319     network=network,
#    2320     timeout=timeout,
#    2321     restart_job_on_worker_restart=restart_job_on_worker_restart,
#    2322     enable_web_access=enable_web_access,
#    2323     experiment=experiment,
#    2324     experiment_run=experiment_run,
#    2325     tensorboard=tensorboard,
#    2326     sync=sync,
#    2327     create_request_timeout=create_request_timeout,
#    2328     disable_retries=disable_retries,
#    2329     persistent_resource_id=persistent_resource_id,
#    2330     scheduling_strategy=scheduling_strategy,
#    2331     max_wait_duration=max_wait_duration,
#    2332 )
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/base.py:863, in optional_sync.<locals>.optional_run_in_thread.<locals>.wrapper(*args, **kwargs)
#     861     if self:
#     862         VertexAiResourceNounWithFutureManager.wait(self)
# --> 863     return method(*args, **kwargs)
#     865 # callbacks to call within the Future (in same Thread)
#     866 internal_callbacks = []
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/jobs.py:2424, in CustomJob._run(self, service_account, network, timeout, restart_job_on_worker_restart, enable_web_access, experiment, experiment_run, tensorboard, sync, create_request_timeout, disable_retries, persistent_resource_id, scheduling_strategy, max_wait_duration)
#    2334 @base.optional_sync()
#    2335 def _run(
#    2336     self,
#    (...)
#    2350     max_wait_duration: Optional[int] = None,
#    2351 ) -> None:
#    2352     """Helper method to ensure network synchronization and to run the configured CustomJob.
#    2353
#    2354     Args:
#    (...)
#    2422             the job will wait indefinitely. The default is 1 day.
#    2423     """
# -> 2424     self.submit(
#    2425         service_account=service_account,
#    2426         network=network,
#    2427         timeout=timeout,
#    2428         restart_job_on_worker_restart=restart_job_on_worker_restart,
#    2429         enable_web_access=enable_web_access,
#    2430         experiment=experiment,
#    2431         experiment_run=experiment_run,
#    2432         tensorboard=tensorboard,
#    2433         create_request_timeout=create_request_timeout,
#    2434         disable_retries=disable_retries,
#    2435         persistent_resource_id=persistent_resource_id,
#    2436         scheduling_strategy=scheduling_strategy,
#    2437         max_wait_duration=max_wait_duration,
#    2438     )
#    2440     self._block_until_complete()
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/jobs.py:2586, in CustomJob.submit(self, service_account, network, timeout, restart_job_on_worker_restart, enable_web_access, experiment, experiment_run, tensorboard, create_request_timeout, disable_retries, persistent_resource_id, scheduling_strategy, max_wait_duration)
#    2579 (
#    2580     self._gca_resource.job_spec.experiment,
#    2581     self._gca_resource.job_spec.experiment_run,
#    2582 ) = self._get_experiment_and_run_resource_name(experiment, experiment_run)
#    2584 _LOGGER.log_create_with_lro(self.__class__)
# -> 2586 self._gca_resource = self.api_client.create_custom_job(
#    2587     parent=self._parent,
#    2588     custom_job=self._gca_resource,
#    2589     timeout=create_request_timeout,
#    2590 )
#    2592 _LOGGER.log_create_complete_with_getter(
#    2593     self.__class__, self._gca_resource, "custom_job"
#    2594 )
#    2596 _LOGGER.info("View Custom Job:\n%s" % self._dashboard_uri())
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform_v1/services/job_service/client.py:1185, in JobServiceClient.create_custom_job(self, request, parent, custom_job, retry, timeout, metadata)
#    1182 self._validate_universe_domain()
#    1184 # Send the request.
# -> 1185 response = rpc(
#    1186     request,
#    1187     retry=retry,
#    1188     timeout=timeout,
#    1189     metadata=metadata,
#    1190 )
#    1192 # Done; return the response.
#    1193 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 The following quota metrics exceed quota limits: aiplatform.googleapis.com/custom_model_training_cpus

# %%
# create an endpoint 
# The endpoint resource provides the service endpoint (URL) you use to request for the prediction
endpoint = aiplatform.Endpoint.create(
  display_name="xgboost_model",
  dedicated_endpoint_enabled=True,
)
# Out:
# Creating Endpoint
# Create Endpoint backing LRO: projects/703919146685/locations/us-central1/endpoints/5957366205034528768/operations/4765707428312383488
# Endpoint created. Resource name: projects/703919146685/locations/us-central1/endpoints/5957366205034528768
# To use this Endpoint in another session:
# endpoint = aiplatform.Endpoint('projects/703919146685/locations/us-central1/endpoints/5957366205034528768')

# %%
# !gcloud endpoints services list
# Out:
# Listed 0 items.

# %%
# deploy model
# When you deploy a model to an endpoint, you associate physical (machine) resources with that model so 
# it can serve online predictions. Online predictions have low latency requirements. Providing resources to the model in advance reduces latency.

aiplatform.init(project=PROJECT_ID, location=LOCATION)

# model doesn't exist yet because CPU quotas error when I start a CustomJob
model = aiplatform.Model(model_name=IMAGE_NAME)

model.deploy(
    endpoint=endpoint,
    deployed_model_display_name=IMAGE_NAME + "-deploy",
    traffic_percentage="0.2",
    traffic_split="0.2",
    machine_type="n1-standard-4",
)
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# Cell In[15], line 7
#       1 # deploy model
#       2 # When you deploy a model to an endpoint, you associate physical (machine) resources with that model so
#       3 # it can serve online predictions. Online predictions have low latency requirements. Providing resources to the model in advance reduces latency.
#       5 aiplatform.init(project=PROJECT_ID, location=LOCATION)
# ----> 7 model = aiplatform.Model(model_name="xgboost_model_train")
#       9 model.deploy(
#      10     endpoint=endpoint,
#      11     deployed_model_display_name="xgboost_train",
#    (...)
#      14     machine_type="n1-standard-4",
#      15 )
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/models.py:4503, in Model.__init__(self, model_name, project, location, credentials, version)
#    4501 # Create a versioned model_name, if it exists, for getting the GCA model
#    4502 versioned_model_name = ModelRegistry._get_versioned_name(model_name, version)
# -> 4503 self._gca_resource = self._get_gca_resource(resource_name=versioned_model_name)
#    4505 # Create ModelRegistry with the unversioned resource name
#    4506 self._registry = ModelRegistry(
#    4507     self.resource_name,
#    4508     location=location,
#    4509     project=project,
#    4510     credentials=credentials,
#    4511 )
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform/base.py:692, in VertexAiResourceNoun._get_gca_resource(self, resource_name, parent_resource_name_fields)
#     672 """Returns GAPIC service representation of client class resource.
#     673
#     674 Args:
#    (...)
#     679         Should not include project and location.
#     680 """
#     681 resource_name = utils.full_resource_name(
#     682     resource_name=resource_name,
#     683     resource_noun=self._resource_noun,
#    (...)
#     689     resource_id_validator=self._resource_id_validator,
#     690 )
# --> 692 return getattr(self.api_client, self._getter_method)(
#     693     name=resource_name, retry=_DEFAULT_RETRY
#     694 )
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/aiplatform_v1/services/model_service/client.py:1043, in ModelServiceClient.get_model(self, request, name, retry, timeout, metadata)
#    1040 self._validate_universe_domain()
#    1042 # Send the request.
# -> 1043 response = rpc(
#    1044     request,
#    1045     retry=retry,
#    1046     timeout=timeout,
#    1047     metadata=metadata,
#    1048 )
#    1050 # Done; return the response.
#    1051 return response
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/anaconda3/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# NotFound: 404 The Model does not exist.
